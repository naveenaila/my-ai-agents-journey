# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation."
messages_r = [{"role": "user", "content": request}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages_r
)
#print(response)
question = response.choices[0].message.content
print(question)
# Out:
# How would you reconcile the tension between individual freedom and collective responsibility in a society facing climate change?

# %%
messages_2 = [{"role": "user", "content": question}]
dict_1 = {}
competitors = []
answer_list = []

# %%
# OpenAI API
model_name = "gpt-5-nano"
response = openai.chat.completions.create(
    model=model_name,
    messages=messages_2
)
#print(response)
answer = response.choices[0].message.content
dict_1[model_name] = answer
answer_list.append(answer)
competitors.append(model_name)

# %%
print(competitors)
# Out:
# ['gpt-5-nano']

# %%
# Anthropic API
model_name = "claude-sonnet-4-5"
claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages_2, max_tokens=1000)
#print(response)
answer = response.content[0].text
dict_1[model_name] = answer
competitors.append(model_name)
answer_list.append(answer)
display(Markdown(answer))
#print(answer_list)
#print(competitors)
# Out:
# I'd start by questioning whether this is truly a zero-sum tension. Many climate solutions actually *expand* certain freedoms while shifting how we exercise others.
#
# **Where they align:**
# - Freedom from pollution, health risks, and climate-driven displacement
# - Individual innovation enabling collective progress (personal solar, EVs, etc.)
# - Democratic participation in shaping climate policy
# - Future generations' freedom to inherit a livable world
#
# **The genuine tensions:**
#
# *Consumption patterns* - This is the sharpest edge. Do I have absolute freedom to emit unlimited carbon regardless of cumulative harm? Most societies already accept limits on activities that harm others (you can't dump toxins in shared water). Climate extends this principle across time and space.
#
# *Scale of coordination needed* - Climate requires collective action that individual choice alone can't achieve. But this mirrors other infrastructure: I benefit from universal vaccination, traffic rules, and fire codes even though they constrain individual choice.
#
# **Possible reconciliation approaches:**
#
# 1. **Price externalities, then let people choose** - Carbon taxes internalize costs without dictating specific behaviors
#
# 2. **Invest in alternatives that are *better*** - Clean energy that's cheaper, cities that are more walkable, etc.
#
# 3. **Distinguish rights from preferences** - Clean air might be a right; a particular car model is a preference
#
# 4. **Democratic legitimacy** - Collective decisions feel less restrictive when genuinely participatory
#
# What's your instinct - does this feel more like sacrificing freedom *for* responsibility, or redefining what meaningful freedom requires?

# %%
print(dict_1[''])
# Out:
# Reconciling individual freedom with collective responsibility for climate action isn’t about choosing one over the other. It’s about designing policies and institutions that align personal choices with the common good, while protecting liberty, fairness, and democratic legitimacy.
#
# A practical framework
#
# - Define freedom as real opportunity, not just absence of coercion.
#   - People should have security, predictable rules, and real options (jobs, energy, mobility, health) to shape their lives.
# - Treat climate action as a shared responsibility with fair burdens.
#   - The costs and benefits should be distributed with special care for the most vulnerable and those at risk of losing livelihoods.
# - Build legitimacy through participation, transparency, and accountability.
#   - Use deliberation and clear performance metrics; allow revisions as circumstances change.
# - Use the least restrictive means first.
#   - Prefer information, incentives, and markets over coercive commands; escalate only when necessary.
# - Ensure a just transition.
#   - Invest in workers and communities affected by the shift away from fossil fuels; provide retraining and social protection.
#
# Policy levers that reconcile freedom with responsibility
#
# - Carbon pricing with revenue recycling
#   - Implement a straightforward carbon price (tax or cap-and-trade) and return most or all revenue to households or communities (e.g., lump-sum dividends, targeted rebates). This preserves freedom of choice while making emissions expensive.
# - Regulatory standards where needed
#   - Minimum efficiency standards for buildings, appliances, vehicles; performance-based targets for industry. Use sunset clauses and regular reviews to avoid overreach.
# - Public investment in low-carbon options
#   - Expand affordable renewable energy, grid modernization, energy efficiency programs, and mass transit so people have better, cheaper, and cleaner options.
# - Local and regional autonomy with guardrails
#   - Allow cities and regions to design solutions tailored to their needs (transit networks, zoning, urban design) within national guidelines to maintain coherence.
# - Equity-centered design
#   - Protect low-income households from regressive effects; offer subsidies, weatherization programs, and support for energy burdened communities; ensure a just transition for workers.
# - Information and labeling
#   - Clear carbon footprint labeling for products; public data on corporate climate performance; consumer education to enable informed choices without coercion.
# - Participatory governance
#   - Deliberative forums, citizen assemblies, and local climate councils to shape policy design, set priorities, and legitimize difficult decisions.
# - International cooperation and border considerations
#   - Align with global efforts to prevent leakage and ensure competitive fairness, while supporting poorer nations’ resilience and transition.
#
# Concrete steps for institutions to take
#
# - Start with a public, trusted price on carbon and a transparent dividend mechanism.
# - Pair pricing with strong, targeted investments in clean energy, efficiency, and jobs.
# - Roll out just-transition programs: retraining, income support during shifts, and community reinvestment.
# - Build robust safety nets and social protections so people don’t fear the costs of action.
# - Create mechanisms for ongoing citizen input and independent evaluation of policy outcomes.
# - Ensure climate policies are adaptable: regular reviews, sunset clauses, and the ability to tweak designs as science and economics evolve.
#
# What this looks like in practice
#
# - A city pilfers no freedoms by default but expands real options:
#   - Implement a local carbon charge on transportation or buildings that funds a universal transit pass and energy retrofit programs.
#   - Require high-efficiency building codes but offer grants and low-interest loans for retrofits.
#   - Launch a citizen assembly to decide priorities for a green budget, ensuring residents have a say in where funds go.
# - An economy where individuals still choose:
#   - You can drive or fly, but the cost reflects the climate impact; rebates cushion the burden for lower-income families; you opt for greener options and still have freedom to decide.
#
# Common objections and responses
#
# - “We’re being paternalistic or restricting freedom.”
#   - Short-term costs may appear restrictive, but the long-term aim is to preserve freedom from climate risks, health harms, and economic shocks. Democratic design and time-limited measures with sunset clauses reduce paternalism concerns.
# - “The costs fall hardest on the wrong people.”
#   - Use revenue recycling, targeted support, and job transition programs to protect the most vulnerable. Gradually phase in measures to allow adaptation.
# - “What about developing countries?”
#   - Support for adaptation, technology transfer, and concessional finance; measures should be globally fair and recognize different starting points.
#
# Bottom line
#
# - Reconciliation happens when policies turn climate action into a set of choices that people can understand, afford, and participate in.
# - The aim is to create a society where individuals feel free to pursue their lives while collectively reducing risk and injustice from climate change.
# - Start with voluntary, transparent, and fair incentives; strengthen them with prudent regulation and robust democratic participation; and ensure a just transition for workers and communities.

# %%
# Google API
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"
response = gemini.chat.completions.create(model=model_name,messages=messages_2)
answer = response
